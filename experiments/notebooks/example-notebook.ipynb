# %% [markdown]
# # Imports: External, plotting, and project

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
import sys
sys.path.append("../..")
from algorithms.mean import mean
from experiments.result_manager import ResultManager
from experiments.evaluation_manager import EvaluationManager

# %% [markdown]
# # Run algorithms

# %%
    rm = ResultManager(ps=[1000, 2000, 3000, 4000, 5000, 6000], num_trials=1000, name="em_test")
    algs = {
        "mean": mean,
        "median": median
    }
    res_df = rm.get_results(algs)

    em = EvaluationManager(rm)
    em.plot_p_vs_accuracy(algs)
    em.plot_p_vs_time(algs)
# Out:
# [ResultRunner.get_data] Generating data...
# [ResultRunner.get_data] Saving data to experiments/data/rm_test.npz

# %%
xs = np.random.normal(size=(100, 100))

# %%
means = np.array([mean(x) for x in xs])

# %% [markdown]
# # Plot results

# %%
plt.plot(means);
